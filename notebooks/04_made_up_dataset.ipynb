# %% [markdown]
# # 04 — Made-up data with a known answer
#
# On real data nobody knows each person's true extra spend, so we cannot say how close to perfect we got. Here we write the rules ourselves — including people who get *worse* when emailed — then run the same pipeline blind and measure what fraction of the perfect plan we captured.

# %%
from causal_uplift.simulate import run_simulation

out = run_simulation()
out

# %% [markdown]
# Look for: capture near 100% when the truth is written in the same features the model sees; sleeping dogs left alone; the honest grade close to the true extra profit of the pipeline's plan.
